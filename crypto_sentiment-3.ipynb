# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
from newsapi.newsapi_client import NewsApiClient

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/jordandass/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
# Read your api key environment variable
load_dotenv("/Users/Jordandass/newsapi.env")
api_key = os.getenv("NEWS_API_KEY")
print(api_key)
# Out:
# ba3b1fafce124c889829475792d636d2

# %%
# Create a newsapi client
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin = newsapi.get_everything(q='bitcoin')

# %%
# Fetch the Ethereum news articles
ethereum = newsapi.get_everything(q='ethereum')

# %%
bitcoin['articles']
# Out:
# [{'source': {'id': 'wired', 'name': 'Wired'},
#   'author': 'Gian M. Volpicelli',
#   'title': 'As Kazakhstan Descends into Chaos, Crypto Miners Are at a Loss',
#   'description': 'The central Asian country became No. 2 in the world for Bitcoin mining. But political turmoil and power cuts have hit hard, and the future looks bleak.',
#   'url': 'https://www.wired.com/story/kazakhstan-cryptocurrency-mining-unrest-energy/',
#   'urlToImage': 'https://media.wired.com/photos/61de2d453e654a13e9a16ef0/191:100/w_1280,c_limit/Business_Kazakhstan-2HDE52K.jpg',
#   'publishedAt': '2022-01-12T12:00:00Z',
#   'content': 'When Denis Rusinovich set up cryptocurrency mining company Maveric Group in Kazakhstan in 2017, he thought he had hit the jackpot. Next door to China and Russia, the country had everything a Bitcoin … [+4140 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Mitchell Clark',
#   'title': 'The International Monetary Fund tells El Salvador it shouldn’t use Bitcoin as legal tender',
#   'description': 'The International Monetary Fund’s executive directors have recommended to El Salvador that it should narrow the scope of its Bitcoin law, making it so that the cryptocurrency is no longer legal tender in the country.',
#   'url': 'https://www.theverge.com/2022/1/25/22901374/el-salvador-bitcoin-international-monetary-fund-crypto',
#   'urlToImage': 'https://cdn.vox-cdn.com/thumbor/altkKN7BnaLUpbAVPi6j4xmC2Ug=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/13546110/acastro_181126_1777_bitcoin_0001.jpg',
#   'publishedAt': '2022-01-25T22:11:14Z',
#   'content': 'El Salvador introduced Bitcoin as a legal tender alongside the US dollar in 2021. | Illustration by Alex Castro / The Verge\r\n\n \n\n The International Monetary Fund’s executive board has recommended El … [+2691 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Jon Porter',
#   'title': 'Jack Dorsey’s Block is working to make Bitcoin mining easier',
#   'description': 'Block is working on building an “open Bitcoin mining system,” its CEO Jack Dorsey has announced. The company’s goals for the system are for it to be easily available, reliable, and relatively power efficient.',
#   'url': 'https://www.theverge.com/2022/1/14/22883500/jack-dorsey-block-bitcoin-mining-system-open-source-mainstream',
#   'urlToImage': 'https://cdn.vox-cdn.com/thumbor/NE548fVufAlHoBliurOdnG-lfuw=/0x215:3000x1786/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/23168502/1321753348.jpg',
#   'publishedAt': '2022-01-14T13:46:28Z',
#   'content': 'Were officially building an open Bitcoin mining system\r\nPhoto by Joe Raedle/Getty Images\r\nBlock, the payment company formerly known as Square, is working on building an open Bitcoin mining system, it… [+2078 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Corin Faife',
#   'title': 'DeepDotWeb operator sentenced to eight years for money laundering',
#   'description': 'The operator of DeepDotWeb, a site that indexed dark net marketplaces accessible through Tor browser, was sentenced to eight years after pleading guilty to money laundering using Bitcoin.',
#   'url': 'https://www.theverge.com/2022/1/27/22904803/deepdotweb-operator-sentenced-money-laundering-bitcoin-darknet-fbi',
#   'urlToImage': 'https://cdn.vox-cdn.com/thumbor/mde_l3lUC4muDPEFG7LYrUz0O3g=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/8921023/acastro_bitcoin_2.jpg',
#   'publishedAt': '2022-01-27T18:16:57Z',
#   'content': 'Israeli national Tal Prihar pled guilty to routing money from kickbacks through Bitcoin and shell companies \r\nIllustration by Alex Castro / The Verge\r\nIn the culmination of a two-year legal process, … [+1448 chars]'},
#  {'source': {'id': 'the-verge', 'name': 'The Verge'},
#   'author': 'Corin Faife',
#   'title': 'Crypto.com admits over $30 million stolen by hackers',
#   'description': 'Cryptocurrency exchange Crypto.com has said that $15 million in ethereum and $18 million in bitcoin were stolen by hackers in a security breach',
#   'url': 'https://www.theverge.com/2022/1/20/22892958/crypto-com-exchange-hack-bitcoin-ethereum-security',
#   'urlToImage': 'https://cdn.vox-cdn.com/thumbor/mde_l3lUC4muDPEFG7LYrUz0O3g=/0x146:2040x1214/fit-in/1200x630/cdn.vox-cdn.com/uploads/chorus_asset/file/8921023/acastro_bitcoin_2.jpg',
#   'publishedAt': '2022-01-20T13:23:31Z',
#   'content': 'In a new blog post the company said that 4,836 ETH and 443 bitcoin were taken\r\nIllustration by Alex Castro / The Verge\r\nIn a blog post published in the early hours of Thursday morning, cryptocurrency… [+2004 chars]'},
#  {'source': {'id': None, 'name': 'Blogspot.com'},
#   'author': 'noreply@blogger.com (Unknown)',
#   'title': 'Bitcoin Extends Slide, Has Fallen More Than 50% From Record High',
#   'description': 'Bitcoin, the largest digital asset, extended its decline Saturday, and has now shed more than 50% from its record high in November.Bitcoin’s decline since hitting the record has wiped out more than $600 billion in market value, and over $1 trillion has been l…',
#   'url': 'https://techncruncher.blogspot.com/2022/01/bitcoin-extends-slide-has-fallen-more.html',
#   'urlToImage': 'https://blogger.googleusercontent.com/img/a/AVvXsEhX63nKoO0bHPlhUmotmBnAoeop0qBhuBYbRRw7FyK-ryX64_wAoLezFw3iJgY4g43RT4MEGA0vlqNqFd2OWXghAxs0XLq7BNMreTsT1sgd3z-WYsXvhzYq5EzDcA-Erbu3FwT119zR-UNF-vISiwbNtqHMRYl7_lWt6evRK1xWIazcvKx40HKJ5SdiAw=w1200-h630-p-k-no-nu',
#   'publishedAt': '2022-01-22T13:35:00Z',
#   'content': 'Bitcoin, the largest digital asset, extended its decline Saturday, and has now shed more than 50% from its record high in November.Bitcoin’s decline since hitting the record has wiped out more than $… [+567 chars]'},
#  {'source': {'id': 'engadget', 'name': 'Engadget'},
#   'author': 'Mariella Moon',
#   'title': "Block is officially building an 'open Bitcoin mining system,' says founder Jack Dorsey",
#   'description': 'Block founder Jack Dorsey has announced on Twitter that the company is officially building an open bitcoin mining system. Dorsey first announced in October last year that the digital payments provider, then known as Square, was considering working on the proj…',
#   'url': 'https://www.engadget.com/jack-dorseys-block-is-officially-building-an-open-bitcoin-mining-system-114033482.html',
#   'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-12/b08eca30-67a7-11ec-bfef-a5351ba20ef6',
#   'publishedAt': '2022-01-14T11:40:33Z',
#   'content': 'Block founder Jack Dorsey has announced on Twitter that the company is officially building an open bitcoin mining system. Dorsey first announced in October last year that the digital payments provide… [+1584 chars]'},
#  {'source': {'id': None, 'name': 'Blogspot.com'},
#   'author': 'noreply@blogger.com (Unknown)',
#   'title': 'Musk says Tesla to accept dogecoin for merchandise',
#   'description': '<table><tr><td></td></tr><tr><td>\xa0Representation of cryptocurrency Dogecoin is seen in this illustration taken November 29, 2021. REUTERS/Dado Ruvic/Illustration/File Photo</td></tr>\r\n</table>Tesla Inc (TSLA.O) will accept the meme-based cryptocurrency dogeco…',
#   'url': 'https://techncruncher.blogspot.com/2022/01/musk-says-tesla-to-accept-dogecoin-for.html',
#   'urlToImage': 'https://blogger.googleusercontent.com/img/a/AVvXsEiAHi2o-pAdNQNqbU6eVnDtHVY2HvIYdHuBHFQXpjzRRvUkNNNjSD8rJIH_TmYn8--wpME7gw7bhfJ6KoISJSNOJQLfYqr-HZT02wXpVXeg0Ar9yGLKD_ZNbToLt0-vBjvldJdotQOlbaWzlZonZIIINp6eG1v0xyMZdNVTVX4hq23Qkx6XGF9NIurkfw=w1200-h630-p-k-no-nu',
#   'publishedAt': '2022-01-14T14:14:00Z',
#   'content': 'Tesla Inc (TSLA.O) will accept the meme-based cryptocurrency dogecoin as payment for its products such as the "Giga Texas" belt buckle and mini\xa0 electric vehicle models, CEO Elon Musk said on Friday … [+1482 chars]'},
#  {'source': {'id': None, 'name': 'New York Times'},
#   'author': 'Dana Rubinstein, Jonah E. Bromwich and Jeffery C. Mays',
#   'title': 'Eric Adams Is Taking His First Paycheck in Crypto',
#   'description': 'Mr. Adams, who wants New York City to become the global capital for cryptocurrency, will have his paycheck converted into Bitcoin and Ethereum.',
#   'url': 'https://www.nytimes.com/2022/01/20/nyregion/eric-adams-bitcoin-cryptocurrency.html',
#   'urlToImage': 'https://static01.nyt.com/images/2022/01/20/nyregion/20adams-crypto01/20adams-crypto01-facebookJumbo.jpg',
#   'publishedAt': '2022-01-20T19:54:48Z',
#   'content': 'On some level, the new mayor is simply employing an age-old political strategy: making overtures to the business community. Fintech is a growing field in New York City, and blockchain-based companies… [+1562 chars]'},
#  {'source': {'id': 'wired', 'name': 'Wired'},
#   'author': 'Gian M. Volpicelli',
#   'title': 'Gibraltar Could Launch the World’s First Crypto Stock Exchange',
#   'description': '“The Rock” hopes a new stock exchange will attract crypto millionaires who want to avoid hefty taxes.',
#   'url': 'https://www.wired.com/story/gibraltar-crypto-exchange/',
#   'urlToImage': 'https://media.wired.com/photos/61f0b4bf03f9ae99229f47d4/191:100/w_1280,c_limit/Business_Gibraltar-1208348908.jpg',
#   'publishedAt': '2022-01-26T12:00:00Z',
#   'content': 'British entrepreneur and financier Richard ODell Poulden hopes that his new venture will relieve the plight of an underserved cohort: Bitcoin billionaires who want to buy a house.\r\nIn October, Poulde… [+3364 chars]'},
#  {'source': {'id': None, 'name': 'Blogspot.com'},
#   'author': 'noreply@blogger.com (Unknown)',
#   'title': 'Russian c.bank proposes banning cryptocurrencies, crypto mining',
#   'description': "<table><tr><td></td></tr><tr><td>Representations of virtual cryptocurrencies are seen in this illustration taken November 28, 2021. REUTERS/Dado Ruvic/Illustration/File Photo</td></tr>\r\n</table>Russia's central bank on Thursday proposed banning the use and mi…",
#   'url': 'https://techncruncher.blogspot.com/2022/01/russian-cbank-proposes-banning.html',
#   'urlToImage': 'https://blogger.googleusercontent.com/img/a/AVvXsEh8Ab2fniYX1LMiTt-SPNcljyB-NxzIH1dlQTxEvcspfJZA-dwAY1rGM3kB4TV9RsJFUZg-x_0n7tfSr8j-WBwrBpsKE543Zdyd75jKXHVcGwSjeuqaueLN4BpkzkxjM3ik7yYdc9yCr_qRRy32QlvV9DtvFZefdtdqiYPTvpZHgVUVFKfbADao2NjVIQ=w1200-h630-p-k-no-nu',
#   'publishedAt': '2022-01-20T12:56:00Z',
#   'content': "Russia's central bank on Thursday proposed banning the use and mining of cryptocurrencies\xa0on Russian territory, citing threats to financial stability, citizens' wellbeing and its monetary policy sove… [+2149 chars]"},
#  {'source': {'id': 'bbc-news', 'name': 'BBC News'},
#   'author': 'https://www.facebook.com/bbcnews',
#   'title': 'IMF urges El Salvador to remove Bitcoin as legal tender',
#   'description': 'Officials say the decision poses risks to financial stability and consumer protection in the country.',
#   'url': 'https://www.bbc.co.uk/news/world-latin-america-60135552',
#   'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/5D55/production/_118839832_bitcoinstorereuters.jpg',
#   'publishedAt': '2022-01-26T04:54:14Z',
#   'content': 'Image caption, Bitcoin is accepted everywhere for goods and services in El Salvador, alongside the US dollar\r\nThe International Monetary Fund (IMF) has urged El Salvador to reverse its decision to ma… [+1846 chars]'},
#  {'source': {'id': None, 'name': 'Blogspot.com'},
#   'author': 'noreply@blogger.com (Unknown)',
#   'title': "Crypto CEO becomes one of the world's richest billionaires",
#   'description': '<table><tr><td></td></tr><tr><td>"Zhao Changpeng has become the world\'s biggest cryptocurrency billionaire(Image: Bloomberg via Getty Images)</td></tr>\r\n</table>A cryptocurrency CEO has become one of the richest people on the planet.Changpeng "CZ" Zhao, who m…',
#   'url': 'https://techncruncher.blogspot.com/2022/01/crypto-ceo-becomes-one-of-worlds.html',
#   'urlToImage': 'https://blogger.googleusercontent.com/img/a/AVvXsEj978sCv3gLJg0vBKUzMeJLfis0RTv9EXx5SBp1dBHmTSW5zI946qp2JBTkwo-IFL5ZNv2OQRdVr1Y7qR__vDrWKrS1TUMgRVxmAoHhDXfO4R5FII7PwGwWUvzIjR9wlfuZQIKBl-lprQH3Qmpw1DZQSJED9v3GGMsDJcaxBCkpPDtCBuKi15my8tFvLA=w1200-h630-p-k-no-nu',
#   'publishedAt': '2022-01-11T12:29:00Z',
#   'content': 'A cryptocurrency CEO has become one of the richest people on the planet.Changpeng "CZ" Zhao, who manages the Binance cryptocurrency exchange, has joined the ranks of the world\'s top billionaires, wit… [+3566 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': 'Reuters Staff',
#   'title': "U.S. SEC rejects Fidelity's Wise Origin spot bitcoin ETF - Reuters.com",
#   'description': "The U.S. Securities and Exchange Commission on Thursday rejected a proposal to offer spot bitcoin exchange-traded funds (ETF) from Fidelity's Wise Origin Bitcoin Trust.",
#   'url': 'https://www.reuters.com/article/crypto-currency-sec-etf-idUSL4N2U62Z0',
#   'urlToImage': 'https://s1.reutersmedia.net/resources_v2/images/rcom-default.png?w=800',
#   'publishedAt': '2022-01-27T15:19:00Z',
#   'content': 'By Reuters Staff\r\nJan 26 (Reuters) - The U.S. Securities and Exchange Commission on Thursday rejected a proposal to offer spot bitcoin exchange-traded funds (ETF) from Fidelitys Wise Origin Bitcoin T… [+202 chars]'},
#  {'source': {'id': 'business-insider', 'name': 'Business Insider'},
#   'author': 'hmalik@insider.com (Hamza Fareed Malik)',
#   'title': 'Jack Dorsey says Block is building a bitcoin mining system so that anyone can easily buy a rig',
#   'description': 'Block is officially building a bitcoin mining system to make mining bitcoin "more distributed and efficient."',
#   'url': 'https://markets.businessinsider.com/news/currencies/block-bitcoin-mining-jack-dorsey-rig-crypto-open-anyone-buy-2022-1',
#   'urlToImage': 'https://images2.markets.businessinsider.com/61e16983c5e27c00185b8d80?format=jpeg',
#   'publishedAt': '2022-01-14T12:34:09Z',
#   'content': 'Jack Dorsey onstage at a bitcoin convention in June.Joe Raedle/Getty Images\r\nBlock is going ahead with building a bitcoin mining system that will be open to individuals and businesses worldwide, its … [+2459 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Shoshana Wodinsky',
#   'title': 'Crypto Dev Says He’s Spending $500,000 on a Statue of Elon Musk’s Head on a Goat’s Body',
#   'description': 'Between Bitcoin-themed superspreader events and cringey branded NFT’s, those within the crypto community have set a high bar for devising the worst ways to hawk their currency of choice. But this week, the creators of an Elon Musk-themed cryptocurrency dubbed…',
#   'url': 'https://gizmodo.com/crypto-dev-says-he-s-spending-500-000-on-a-statue-of-e-1848321336',
#   'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/747f9809de270cde233f59fd229fd8c4.png',
#   'publishedAt': '2022-01-07T19:30:00Z',
#   'content': 'Between Bitcoin-themed superspreader events and cringey branded NFTs, those within the crypto community have set a high bar for devising the worst ways to hawk their currency of choice. But this week… [+3034 chars]'},
#  {'source': {'id': 'engadget', 'name': 'Engadget'},
#   'author': 'Igor Bonifacic',
#   'title': 'Robinhood opens cryptocurrency wallet to beta testers',
#   'description': 'Back in September\r\n, Robinhood announced plans to test a cryptocurrency wallet within its app. At the time, the company said it would open the beta to a small number of people before expanding availability ahead of a full-scale release. If you joined the wait…',
#   'url': 'https://www.engadget.com/robinhood-cryptocurrency-wallet-beta-225721593.html',
#   'urlToImage': 'https://s.yimg.com/os/creatr-uploaded-images/2021-09/5035fef0-1bd6-11ec-b7e5-a610838e0b98',
#   'publishedAt': '2022-01-21T22:57:21Z',
#   'content': 'Back in September\r\n, Robinhood announced plans to test a cryptocurrency wallet within its app. At the time, the company said it would open the beta to a small number of people before expanding availa… [+1069 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Matt Novak',
#   'title': 'Crypto.com Finally Acknowledges $34 Million Stolen by Hackers',
#   'description': 'Trading platform Crypto.com lost about $34 million worth of cryptocurrency in a hack on Monday, according to a new blog post by the company published overnight. The company had previously declined to say much about the hack, which forced users to stop withdra…',
#   'url': 'https://gizmodo.com/crypto-com-finally-acknowledges-34-million-stolen-by-h-1848389819',
#   'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/3c7e7ff30b167a88b03f3ef59220cd22.jpg',
#   'publishedAt': '2022-01-20T12:00:00Z',
#   'content': 'Trading platform Crypto.com lost about $34 million worth of cryptocurrency in a hack on Monday, according to a new blog post by the company published overnight. The company had previously declined to… [+2933 chars]'},
#  {'source': {'id': None, 'name': 'Gizmodo.com'},
#   'author': 'Mack DeGeurin',
#   'title': 'EU Regulator Wants to Ban Proof of Work Crypto Mining to Avoid Climate Disaster',
#   'description': 'One of the European Union’s top regulators has a new proposal for reducing cryptocurrency’s carbon footprint: ban proof of work mining. The proposed prohibition, suggested by European Securities and Markets Authority Vice Chair Erik Thedéen during a Financial…',
#   'url': 'https://gizmodo.com/european-union-regulator-proof-of-work-bitcoin-ethereum-1848384679',
#   'urlToImage': 'https://i.kinja-img.com/gawker-media/image/upload/c_fill,f_auto,fl_progressive,g_center,h_675,pg_1,q_80,w_1200/e347ce1038984213dcf95a7a9142c961.jpg',
#   'publishedAt': '2022-01-19T17:55:00Z',
#   'content': 'One of the European Unions top regulators has a new proposal for reducing cryptocurrencys carbon footprint: ban proof of work mining. The proposed prohibition, suggested by European Securities and Ma… [+3602 chars]'},
#  {'source': {'id': 'reuters', 'name': 'Reuters'},
#   'author': None,
#   'title': 'CRYPTOVERSE-Bitcoin squeezes smaller rivals to its crown - Reuters',
#   'description': 'Bitcoin is beginning to reassert its dominance over challengers to its cryptocurrency crown.',
#   'url': 'https://www.reuters.com/markets/europe/cryptoverse-bitcoin-squeezes-smaller-rivals-its-crown-2022-02-01/',
#   'urlToImage': 'https://www.reuters.com/resizer/trzf0WaGaNyLC7bG_gRXhD2h0Ag=/1200x628/smart/filters:quality(80)/cloudfront-us-east-2.images.arcpublishing.com/reuters/SLSYKLM3IJPZNNH5EMCYLZA2F4.jpg',
#   'publishedAt': '2022-02-01T06:00:00Z',
#   'content': 'Feb 1 (Reuters) - Bitcoin is beginning to reassert its dominance over challengers to its cryptocurrency crown.\r\nThe original digital coin was assailed by thousands of new "altcoin" competitors in 202… [+3972 chars]'}]

# %%
# Sentiment scores dictionaries
def get_sentiment(score):
    """
    Calculates the sentiment based on the compound score.
    """
    if -0.5 < score < 0.5:
        return 0
    elif score <= -0.5:
        return -1
    elif score >= 0.5:
        return 1
    
title_sent, text_sent, dataframes_list = [], [], []
# Get sentiment for the text and the title
for all_articles in [bitcoin, ethereum]:
    articles = all_articles['articles']
    for article_dict in articles:
        for type_text in ['title', 'description']:
        # Sentiment scoring with VADER
            sentiment = analyzer.polarity_scores(article_dict[type_text])
            compound = sentiment["compound"]
            pos = sentiment["pos"]
            neu = sentiment["neu"]
            neg = sentiment["neg"]
            sent = get_sentiment(compound)

            if type_text == 'title':
                title_sent.append({
            "title_compound": compound,
            "title_pos": pos,
            "title_neu": neu,
            "title_neg": neg,
            "title_sent": sent,})
            else:
                text_sent.append({
            "text_compound": compound,
            "text_pos": pos,
            "text_neu": neu,
            "text_neg": neg,
            "text_sent": sent,})

    # Attaching sentiment columns to the News DataFrame
    title_df = pd.DataFrame(title_sent)
    text_df = pd.DataFrame(text_sent)
    title_text_df = pd.concat([title_df, text_df], axis = 'columns', join = 'inner')
    dataframes_list.append(title_text_df)

# %%
# Create the Bitcoin sentiment scores DataFrame
bitcoin_sent = dataframes_list[0]
bitcoin_sent
# Out:
#     title_compound  title_pos  title_neu  title_neg  title_sent  \
# 0          -0.7184      0.000      0.571      0.429          -1
# 1           0.1280      0.103      0.897      0.000           0
# 2          -0.0258      0.204      0.584      0.212           0
# 3          -0.0258      0.000      0.879      0.121           0
# 4          -0.2500      0.193      0.526      0.281           0
# 5          -0.2500      0.115      0.692      0.192           0
# 6          -0.4404      0.000      0.805      0.195           0
# 7           0.3818      0.271      0.729      0.000           0
# 8           0.0000      0.000      1.000      0.000           0
# 9           0.0000      0.000      1.000      0.000           0
# 10          0.0000      0.000      1.000      0.000           0
# 11          0.1280      0.143      0.857      0.000           0
# 12          0.5267      0.298      0.702      0.000           1
# 13         -0.0258      0.217      0.559      0.224           0
# 14         -0.2500      0.121      0.657      0.222           0
# 15          0.0000      0.000      1.000      0.000           0
# 16          0.0000      0.000      1.000      0.000           0
# 17         -0.4939      0.000      0.686      0.314           0
# 18         -0.8720      0.000      0.526      0.474          -1
# 19          0.0000      0.000      1.000      0.000           0
#
#     text_compound  text_pos  text_neu  text_neg  text_sent
# 0         -0.8047     0.000     0.704     0.296         -1
# 1          0.0258     0.088     0.853     0.059          0
# 2          0.3182     0.133     0.793     0.074          0
# 3         -0.4404     0.000     0.865     0.135          0
# 4         -0.2023     0.094     0.781     0.125          0
# 5          0.5994     0.104     0.896     0.000          1
# 6         -0.4404     0.000     0.932     0.068          0
# 7          0.3818     0.094     0.906     0.000          0
# 8          0.0000     0.000     1.000     0.000          0
# 9          0.5267     0.317     0.577     0.106          1
# 10         0.0000     0.000     1.000     0.000          0
# 11        -0.2732     0.000     0.870     0.130          0
# 12         0.5267     0.105     0.895     0.000          1
# 13         0.6486     0.278     0.615     0.107          1
# 14        -0.4404     0.000     0.828     0.172          0
# 15        -0.3716     0.000     0.937     0.063          0
# 16         0.0772     0.031     0.969     0.000          0
# 17        -0.6808     0.041     0.797     0.162         -1
# 18        -0.0772     0.130     0.782     0.088          0
# 19         0.2960     0.225     0.775     0.000          0

# %%
# Create the Ethereum sentiment scores DataFrame
eth_sent = dataframes_list[1]
eth_sent
# Out:
#     title_compound  title_pos  title_neu  title_neg  title_sent  \
# 0          -0.7184      0.000      0.571      0.429          -1
# 1           0.1280      0.103      0.897      0.000           0
# 2          -0.0258      0.204      0.584      0.212           0
# 3          -0.0258      0.000      0.879      0.121           0
# 4          -0.2500      0.193      0.526      0.281           0
# 5          -0.2500      0.115      0.692      0.192           0
# 6          -0.4404      0.000      0.805      0.195           0
# 7           0.3818      0.271      0.729      0.000           0
# 8           0.0000      0.000      1.000      0.000           0
# 9           0.0000      0.000      1.000      0.000           0
# 10          0.0000      0.000      1.000      0.000           0
# 11          0.1280      0.143      0.857      0.000           0
# 12          0.5267      0.298      0.702      0.000           1
# 13         -0.0258      0.217      0.559      0.224           0
# 14         -0.2500      0.121      0.657      0.222           0
# 15          0.0000      0.000      1.000      0.000           0
# 16          0.0000      0.000      1.000      0.000           0
# 17         -0.4939      0.000      0.686      0.314           0
# 18         -0.8720      0.000      0.526      0.474          -1
# 19          0.0000      0.000      1.000      0.000           0
# 20         -0.2500      0.193      0.526      0.281           0
# 21         -0.4939      0.000      0.738      0.262           0
# 22          0.0000      0.000      1.000      0.000           0
# 23          0.0000      0.000      1.000      0.000           0
# 24         -0.4939      0.000      0.686      0.314           0
# 25          0.0000      0.000      1.000      0.000           0
# 26          0.0000      0.000      1.000      0.000           0
# 27          0.0000      0.000      1.000      0.000           0
# 28          0.0000      0.000      1.000      0.000           0
# 29         -0.4939      0.000      0.802      0.198           0
# 30         -0.1280      0.000      0.842      0.158           0
# 31          0.0000      0.000      1.000      0.000           0
# 32         -0.4939      0.000      0.775      0.225           0
# 33         -0.5106      0.000      0.708      0.292          -1
# 34         -0.4404      0.000      0.672      0.328           0
# 35          0.0000      0.000      1.000      0.000           0
# 36          0.0000      0.000      1.000      0.000           0
# 37         -0.2263      0.157      0.609      0.235           0
# 38          0.0000      0.000      1.000      0.000           0
# 39          0.0000      0.000      1.000      0.000           0
#
#     text_compound  text_pos  text_neu  text_neg  text_sent
# 0         -0.8047     0.000     0.704     0.296         -1
# 1          0.0258     0.088     0.853     0.059          0
# 2          0.3182     0.133     0.793     0.074          0
# 3         -0.4404     0.000     0.865     0.135          0
# 4         -0.2023     0.094     0.781     0.125          0
# 5          0.5994     0.104     0.896     0.000          1
# 6         -0.4404     0.000     0.932     0.068          0
# 7          0.3818     0.094     0.906     0.000          0
# 8          0.0000     0.000     1.000     0.000          0
# 9          0.5267     0.317     0.577     0.106          1
# 10         0.0000     0.000     1.000     0.000          0
# 11        -0.2732     0.000     0.870     0.130          0
# 12         0.5267     0.105     0.895     0.000          1
# 13         0.6486     0.278     0.615     0.107          1
# 14        -0.4404     0.000     0.828     0.172          0
# 15        -0.3716     0.000     0.937     0.063          0
# 16         0.0772     0.031     0.969     0.000          0
# 17        -0.6808     0.041     0.797     0.162         -1
# 18        -0.0772     0.130     0.782     0.088          0
# 19         0.2960     0.225     0.775     0.000          0
# 20        -0.2023     0.094     0.781     0.125          0
# 21         0.3400     0.059     0.941     0.000          0
# 22         0.0000     0.000     1.000     0.000          0
# 23         0.0772     0.031     0.969     0.000          0
# 24        -0.6808     0.041     0.797     0.162         -1
# 25         0.0000     0.000     1.000     0.000          0
# 26         0.0000     0.000     1.000     0.000          0
# 27         0.7579     0.217     0.783     0.000          1
# 28        -0.4340     0.033     0.868     0.099          0
# 29        -0.3612     0.000     0.815     0.185          0
# 30        -0.1027     0.250     0.455     0.295          0
# 31        -0.1027     0.250     0.455     0.295          0
# 32         0.4215     0.219     0.781     0.000          0
# 33        -0.2023     0.099     0.739     0.162          0
# 34         0.0516     0.031     0.969     0.000          0
# 35         0.5267     0.317     0.577     0.106          1
# 36         0.0000     0.000     1.000     0.000          0
# 37         0.4588     0.107     0.893     0.000          0
# 38         0.0000     0.000     1.000     0.000          0
# 39         0.2500     0.062     0.938     0.000          0

# %%
# Describe the Bitcoin Sentiment
bitcoin_sent.describe()
# Out:
#        title_compound  title_pos  title_neu  title_neg  title_sent  \
# count       20.000000  20.000000  20.000000  20.000000   20.000000
# mean        -0.109380   0.083250   0.783500   0.133200   -0.050000
# std          0.334077   0.104758   0.180724   0.156502    0.394034
# min         -0.872000   0.000000   0.526000   0.000000   -1.000000
# 25%         -0.250000   0.000000   0.638750   0.000000    0.000000
# 50%         -0.012900   0.000000   0.767000   0.060500    0.000000
# 75%          0.000000   0.155500   1.000000   0.222500    0.000000
# max          0.526700   0.298000   1.000000   0.474000    1.000000
#
#        text_compound   text_pos   text_neu   text_neg  text_sent
# count      20.000000  20.000000  20.000000  20.000000  20.000000
# mean       -0.016530   0.082000   0.838750   0.079250   0.100000
# std         0.436679   0.096901   0.115041   0.078325   0.552506
# min        -0.804700   0.000000   0.577000   0.000000  -1.000000
# 25%        -0.388800   0.000000   0.781750   0.000000   0.000000
# 50%         0.000000   0.064500   0.859000   0.071000   0.000000
# 75%         0.334100   0.111250   0.912500   0.126250   0.000000
# max         0.648600   0.317000   1.000000   0.296000   1.000000

# %%
# Describe the Ethereum Sentiment
eth_sent.describe()
# Out:
#        title_compound  title_pos  title_neu  title_neg  title_sent  \
# count       40.000000  40.000000  40.000000  40.000000   40.000000
# mean        -0.142963   0.050375   0.825700   0.123925   -0.050000
# std          0.282062   0.088798   0.175062   0.144558    0.316228
# min         -0.872000   0.000000   0.526000   0.000000   -1.000000
# 25%         -0.297600   0.000000   0.686000   0.000000    0.000000
# 50%          0.000000   0.000000   0.849500   0.000000    0.000000
# 75%          0.000000   0.106000   1.000000   0.227500    0.000000
# max          0.526700   0.298000   1.000000   0.474000    1.000000
#
#        text_compound   text_pos   text_neu   text_neg  text_sent
# count      40.000000  40.000000  40.000000  40.000000  40.000000
# mean        0.011677   0.086250   0.838400   0.075350   0.075000
# std         0.390104   0.098445   0.145406   0.089513   0.474342
# min        -0.804700   0.000000   0.455000   0.000000  -1.000000
# 25%        -0.220025   0.000000   0.781000   0.000000   0.000000
# 50%         0.000000   0.050000   0.866500   0.061000   0.000000
# 75%         0.323650   0.112750   0.948000   0.126250   0.000000
# max         0.757900   0.317000   1.000000   0.296000   1.000000

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: Bitcoin for title and Eth for descriptions
#
# Q: Which coin had the highest compound score?
#
# A: Bitcoin and Ethereum are tied for highest compound score for titles, but Eth exceeds in descriptions
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin and Ethereum are tied for highest compound score for titles and descriptions

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
import nltk
nltk.download('stopwords')
stops = list(set(stopwords.words('english')))

# Expand the default stopwords list if necessary
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jordandass/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    # Remove the punctuation from text
    text_list = re.findall('\w+', text)
    # Lemmatize words into root words, Convert the words to lowercase, Remove the stop words
    tokens = [lemmatizer.lemmatize(word.lower()) for word in text_list if word.lower() not in stops]
    return tokens

tokenizer('My, name is Jordan. Nice to meet you!')
# Out:
# ['name', 'jordan', 'nice', 'meet']

# %%
token_dataframes = []
words_dict = {}
for all_articles, name in zip([bitcoin, ethereum], ['bitcoin', 'ethereum']):
    articles = all_articles['articles']
    
    rows, title_list, text_list = [], [] ,[]
    for article_dict in articles:
        title_token = tokenizer(article_dict['title'])
        title_list.append(title_token)
        
        text_token = tokenizer(article_dict['description'])
        text_list.append(text_token)
        
        rows.append([title_token, text_token])
    df = pd.DataFrame(rows, columns = [f'{name}_title', f'{name}_description'])
    token_dataframes.append(df)
    
    words_dict[f'{name}_title'] = title_list
    words_dict[f'{name}_text'] = text_list

# %%
# Create a new tokens column for Bitcoin
bitcoin_token = token_dataframes[0]
bitcoin_token
# Out:
#                                         bitcoin_title  \
# 0   [kazakhstan, descends, chaos, crypto, miner, l...
# 1   [international, monetary, fund, tell, el, salv...
# 2   [jack, dorsey, block, working, make, bitcoin, ...
# 3   [deepdotweb, operator, sentenced, eight, year,...
# 4   [crypto, com, admits, 30, million, stolen, hac...
# 5   [bitcoin, extends, slide, fallen, 50, record, ...
# 6   [block, officially, building, open, bitcoin, m...
# 7   [musk, say, tesla, accept, dogecoin, merchandise]
# 8       [eric, adam, taking, first, paycheck, crypto]
# 9   [gibraltar, could, launch, world, first, crypt...
# 10  [russian, c, bank, proposes, banning, cryptocu...
# 11  [imf, urge, el, salvador, remove, bitcoin, leg...
# 12  [crypto, ceo, becomes, one, world, richest, bi...
# 13  [u, sec, reject, fidelity, wise, origin, spot,...
# 14  [jack, dorsey, say, block, building, bitcoin, ...
# 15  [crypto, dev, say, spending, 500, 000, statue,...
# 16  [robinhood, open, cryptocurrency, wallet, beta...
# 17  [crypto, com, finally, acknowledges, 34, milli...
# 18  [eu, regulator, want, ban, proof, work, crypto...
# 19  [cryptoverse, bitcoin, squeeze, smaller, rival...
#
#                                   bitcoin_description
# 0   [central, asian, country, became, 2, world, bi...
# 1   [international, monetary, fund, executive, dir...
# 2   [block, working, building, open, bitcoin, mini...
# 3   [operator, deepdotweb, site, indexed, dark, ne...
# 4   [cryptocurrency, exchange, crypto, com, said, ...
# 5   [bitcoin, largest, digital, asset, extended, d...
# 6   [block, founder, jack, dorsey, announced, twit...
# 7   [table, tr, td, td, tr, tr, td, representation...
# 8   [mr, adam, want, new, york, city, become, glob...
# 9   [rock, hope, new, stock, exchange, attract, cr...
# 10  [table, tr, td, td, tr, tr, td, representation...
# 11  [official, say, decision, pose, risk, financia...
# 12  [table, tr, td, td, tr, tr, td, zhao, changpen...
# 13  [u, security, exchange, commission, thursday, ...
# 14  [block, officially, building, bitcoin, mining,...
# 15  [bitcoin, themed, superspreader, event, cringe...
# 16  [back, september, robinhood, announced, plan, ...
# 17  [trading, platform, crypto, com, lost, 34, mil...
# 18  [one, european, union, top, regulator, new, pr...
# 19  [bitcoin, beginning, reassert, dominance, chal...

# %%
# Create a new tokens column for Ethereum
eth_token = token_dataframes[1]
eth_token
# Out:
#                                        ethereum_title  \
# 0   [crypto, com, admits, 30, million, stolen, hac...
# 1   [hacker, launder, 15, million, stolen, crypto,...
# 2       [eric, adam, taking, first, paycheck, crypto]
# 3   [robinhood, open, cryptocurrency, wallet, beta...
# 4   [crypto, com, finally, acknowledges, 34, milli...
# 5   [looksrare, reportedly, generated, 8b, ethereu...
# 6                 [mine, ethereum, step, step, guide]
# 7              [2, meme, stock, beat, ethereum, 2021]
# 8   [ethereum, inventor, want, replace, pregnant, ...
# 9   [crypto, exchange, shuts, withdrawal, hacker, ...
# 10                  [race, dominate, defi, ecosystem]
# 11                     [race, power, defi, ecosystem]
# 12  [blockchain, platform, wormhole, say, retrieve...
# 13  [hacker, steal, 320m, blockchain, platform, wo...
# 14  [crypto, com, loses, 34, million, hack, affect...
# 15  [gibraltar, could, launch, world, first, crypt...
# 16            [bitcoin, surge, 8, 82, 40611, reuters]
# 17  [blockchain, could, solve, problem, digital, i...
# 18  [new, york, city, mayor, eric, adam, convert, ...
# 19  [gamestop, tap, immutable, x, nft, marketplace...
#
#                                  ethereum_description
# 0   [cryptocurrency, exchange, crypto, com, said, ...
# 1   [hacker, made, roughly, 15, million, ethereum,...
# 2   [mr, adam, want, new, york, city, become, glob...
# 3   [back, september, robinhood, announced, plan, ...
# 4   [trading, platform, crypto, com, lost, 34, mil...
# 5   [looksrare, seemingly, came, nowhere, become, ...
# 6   [ethereum, mining, lot, accessible, everything...
# 7   [investor, interest, growing, cryptocurrency, ...
# 8   [crypto, bros, never, tire, sharing, utopian, ...
# 9   [crypto, com, issued, statement, multiple, use...
# 10                  [ethereum, losing, market, share]
# 11                  [ethereum, losing, market, share]
# 12  [developer, behind, popular, blockchain, bridg...
# 13  [developer, behind, popular, blockchain, bridg...
# 14  [interview, bloomberg, tv, crypto, com, chief,...
# 15  [rock, hope, new, stock, exchange, attract, cr...
# 16  [bitcoin, surged, 8, 82, 40, 611, 4, 2202, gmt...
# 17  [vitalik, buterin, founder, ethereum, asked, l...
# 18  [new, york, city, mayor, eric, adam, confirmed...
# 19  [gamestop, corp, href, http, www, reuters, com...

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
bitcoin_title = words_dict['bitcoin_title']

bitcoin_text = words_dict['bitcoin_text']

eth_title = words_dict['ethereum_title']

eth_text = words_dict['ethereum_text']

# %%
# Generate the Bitcoin N-grams where N=2
ngram_list = []
for text_type in [bitcoin_title, bitcoin_text]:
    bitcoin_ngram = []
    for text in text_type:
        bitcoin_ngram += ngrams(text, n=2)
    bitcoin_ngram = Counter(bitcoin_ngram)
    ngram_list.append(bitcoin_ngram)

bitcoin_title_ngram = ngram_list[0]
bitcoin_text_ngram = ngram_list[1]

display(bitcoin_title_ngram)
display(bitcoin_text_ngram)
# Out:
# Counter({('kazakhstan', 'descends'): 1,
#          ('descends', 'chaos'): 1,
#          ('chaos', 'crypto'): 1,
#          ('crypto', 'miner'): 1,
#          ('miner', 'loss'): 1,
#          ('international', 'monetary'): 1,
#          ('monetary', 'fund'): 1,
#          ('fund', 'tell'): 1,
#          ('tell', 'el'): 1,
#          ('el', 'salvador'): 2,
#          ('salvador', 'use'): 1,
#          ('use', 'bitcoin'): 1,
#          ('bitcoin', 'legal'): 2,
#          ('legal', 'tender'): 2,
#          ('jack', 'dorsey'): 3,
#          ('dorsey', 'block'): 1,
#          ('block', 'working'): 1,
#          ('working', 'make'): 1,
#          ('make', 'bitcoin'): 1,
#          ('bitcoin', 'mining'): 3,
#          ('mining', 'easier'): 1,
#          ('deepdotweb', 'operator'): 1,
#          ('operator', 'sentenced'): 1,
#          ('sentenced', 'eight'): 1,
#          ('eight', 'year'): 1,
#          ('year', 'money'): 1,
#          ('money', 'laundering'): 1,
#          ('crypto', 'com'): 2,
#          ('com', 'admits'): 1,
#          ('admits', '30'): 1,
#          ('30', 'million'): 1,
#          ('million', 'stolen'): 2,
#          ('stolen', 'hacker'): 2,
#          ('bitcoin', 'extends'): 1,
#          ('extends', 'slide'): 1,
#          ('slide', 'fallen'): 1,
#          ('fallen', '50'): 1,
#          ('50', 'record'): 1,
#          ('record', 'high'): 1,
#          ('block', 'officially'): 1,
#          ('officially', 'building'): 1,
#          ('building', 'open'): 1,
#          ('open', 'bitcoin'): 1,
#          ('mining', 'system'): 2,
#          ('system', 'say'): 1,
#          ('say', 'founder'): 1,
#          ('founder', 'jack'): 1,
#          ('musk', 'say'): 1,
#          ('say', 'tesla'): 1,
#          ('tesla', 'accept'): 1,
#          ('accept', 'dogecoin'): 1,
#          ('dogecoin', 'merchandise'): 1,
#          ('eric', 'adam'): 1,
#          ('adam', 'taking'): 1,
#          ('taking', 'first'): 1,
#          ('first', 'paycheck'): 1,
#          ('paycheck', 'crypto'): 1,
#          ('gibraltar', 'could'): 1,
#          ('could', 'launch'): 1,
#          ('launch', 'world'): 1,
#          ('world', 'first'): 1,
#          ('first', 'crypto'): 1,
#          ('crypto', 'stock'): 1,
#          ('stock', 'exchange'): 1,
#          ('russian', 'c'): 1,
#          ('c', 'bank'): 1,
#          ('bank', 'proposes'): 1,
#          ('proposes', 'banning'): 1,
#          ('banning', 'cryptocurrencies'): 1,
#          ('cryptocurrencies', 'crypto'): 1,
#          ('crypto', 'mining'): 2,
#          ('imf', 'urge'): 1,
#          ('urge', 'el'): 1,
#          ('salvador', 'remove'): 1,
#          ('remove', 'bitcoin'): 1,
#          ('crypto', 'ceo'): 1,
#          ('ceo', 'becomes'): 1,
#          ('becomes', 'one'): 1,
#          ('one', 'world'): 1,
#          ('world', 'richest'): 1,
#          ('richest', 'billionaire'): 1,
#          ('u', 'sec'): 1,
#          ('sec', 'reject'): 1,
#          ('reject', 'fidelity'): 1,
#          ('fidelity', 'wise'): 1,
#          ('wise', 'origin'): 1,
#          ('origin', 'spot'): 1,
#          ('spot', 'bitcoin'): 1,
#          ('bitcoin', 'etf'): 1,
#          ('etf', 'reuters'): 1,
#          ('reuters', 'com'): 1,
#          ('dorsey', 'say'): 1,
#          ('say', 'block'): 1,
#          ('block', 'building'): 1,
#          ('building', 'bitcoin'): 1,
#          ('system', 'anyone'): 1,
#          ('anyone', 'easily'): 1,
#          ('easily', 'buy'): 1,
#          ('buy', 'rig'): 1,
#          ('crypto', 'dev'): 1,
#          ('dev', 'say'): 1,
#          ('say', 'spending'): 1,
#          ('spending', '500'): 1,
#          ('500', '000'): 1,
#          ('000', 'statue'): 1,
#          ('statue', 'elon'): 1,
#          ('elon', 'musk'): 1,
#          ('musk', 'head'): 1,
#          ('head', 'goat'): 1,
#          ('goat', 'body'): 1,
#          ('robinhood', 'open'): 1,
#          ('open', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'wallet'): 1,
#          ('wallet', 'beta'): 1,
#          ('beta', 'tester'): 1,
#          ('com', 'finally'): 1,
#          ('finally', 'acknowledges'): 1,
#          ('acknowledges', '34'): 1,
#          ('34', 'million'): 1,
#          ('eu', 'regulator'): 1,
#          ('regulator', 'want'): 1,
#          ('want', 'ban'): 1,
#          ('ban', 'proof'): 1,
#          ('proof', 'work'): 1,
#          ('work', 'crypto'): 1,
#          ('mining', 'avoid'): 1,
#          ('avoid', 'climate'): 1,
#          ('climate', 'disaster'): 1,
#          ('cryptoverse', 'bitcoin'): 1,
#          ('bitcoin', 'squeeze'): 1,
#          ('squeeze', 'smaller'): 1,
#          ('smaller', 'rival'): 1,
#          ('rival', 'crown'): 1,
#          ('crown', 'reuters'): 1})
# Counter({('central', 'asian'): 1,
#          ('asian', 'country'): 1,
#          ('country', 'became'): 1,
#          ('became', '2'): 1,
#          ('2', 'world'): 1,
#          ('world', 'bitcoin'): 1,
#          ('bitcoin', 'mining'): 4,
#          ('mining', 'political'): 1,
#          ('political', 'turmoil'): 1,
#          ('turmoil', 'power'): 1,
#          ('power', 'cut'): 1,
#          ('cut', 'hit'): 1,
#          ('hit', 'hard'): 1,
#          ('hard', 'future'): 1,
#          ('future', 'look'): 1,
#          ('look', 'bleak'): 1,
#          ('international', 'monetary'): 1,
#          ('monetary', 'fund'): 1,
#          ('fund', 'executive'): 1,
#          ('executive', 'director'): 1,
#          ('director', 'recommended'): 1,
#          ('recommended', 'el'): 1,
#          ('el', 'salvador'): 1,
#          ('salvador', 'narrow'): 1,
#          ('narrow', 'scope'): 1,
#          ('scope', 'bitcoin'): 1,
#          ('bitcoin', 'law'): 1,
#          ('law', 'making'): 1,
#          ('making', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'longer'): 1,
#          ('longer', 'legal'): 1,
#          ('legal', 'tender'): 1,
#          ('tender', 'country'): 1,
#          ('block', 'working'): 1,
#          ('working', 'building'): 1,
#          ('building', 'open'): 2,
#          ('open', 'bitcoin'): 2,
#          ('mining', 'system'): 3,
#          ('system', 'ceo'): 1,
#          ('ceo', 'jack'): 1,
#          ('jack', 'dorsey'): 2,
#          ('dorsey', 'announced'): 2,
#          ('announced', 'company'): 1,
#          ('company', 'goal'): 1,
#          ('goal', 'system'): 1,
#          ('system', 'easily'): 1,
#          ('easily', 'available'): 1,
#          ('available', 'reliable'): 1,
#          ('reliable', 'relatively'): 1,
#          ('relatively', 'power'): 1,
#          ('power', 'efficient'): 1,
#          ('operator', 'deepdotweb'): 1,
#          ('deepdotweb', 'site'): 1,
#          ('site', 'indexed'): 1,
#          ('indexed', 'dark'): 1,
#          ('dark', 'net'): 1,
#          ('net', 'marketplace'): 1,
#          ('marketplace', 'accessible'): 1,
#          ('accessible', 'tor'): 1,
#          ('tor', 'browser'): 1,
#          ('browser', 'sentenced'): 1,
#          ('sentenced', 'eight'): 1,
#          ('eight', 'year'): 1,
#          ('year', 'pleading'): 1,
#          ('pleading', 'guilty'): 1,
#          ('guilty', 'money'): 1,
#          ('money', 'laundering'): 1,
#          ('laundering', 'using'): 1,
#          ('using', 'bitcoin'): 1,
#          ('cryptocurrency', 'exchange'): 1,
#          ('exchange', 'crypto'): 1,
#          ('crypto', 'com'): 2,
#          ('com', 'said'): 1,
#          ('said', '15'): 1,
#          ('15', 'million'): 1,
#          ('million', 'ethereum'): 1,
#          ('ethereum', '18'): 1,
#          ('18', 'million'): 1,
#          ('million', 'bitcoin'): 1,
#          ('bitcoin', 'stolen'): 1,
#          ('stolen', 'hacker'): 1,
#          ('hacker', 'security'): 1,
#          ('security', 'breach'): 1,
#          ('bitcoin', 'largest'): 1,
#          ('largest', 'digital'): 1,
#          ('digital', 'asset'): 1,
#          ('asset', 'extended'): 1,
#          ('extended', 'decline'): 1,
#          ('decline', 'saturday'): 1,
#          ('saturday', 'shed'): 1,
#          ('shed', '50'): 1,
#          ('50', 'record'): 1,
#          ('record', 'high'): 1,
#          ('high', 'november'): 1,
#          ('november', 'bitcoin'): 1,
#          ('bitcoin', 'decline'): 1,
#          ('decline', 'since'): 1,
#          ('since', 'hitting'): 1,
#          ('hitting', 'record'): 1,
#          ('record', 'wiped'): 1,
#          ('wiped', '600'): 1,
#          ('600', 'billion'): 1,
#          ('billion', 'market'): 1,
#          ('market', 'value'): 1,
#          ('value', '1'): 1,
#          ('1', 'trillion'): 1,
#          ('trillion', 'l'): 1,
#          ('block', 'founder'): 1,
#          ('founder', 'jack'): 1,
#          ('announced', 'twitter'): 1,
#          ('twitter', 'company'): 1,
#          ('company', 'officially'): 1,
#          ('officially', 'building'): 2,
#          ('system', 'dorsey'): 1,
#          ('dorsey', 'first'): 1,
#          ('first', 'announced'): 1,
#          ('announced', 'october'): 1,
#          ('october', 'last'): 1,
#          ('last', 'year'): 1,
#          ('year', 'digital'): 1,
#          ('digital', 'payment'): 1,
#          ('payment', 'provider'): 1,
#          ('provider', 'known'): 1,
#          ('known', 'square'): 1,
#          ('square', 'considering'): 1,
#          ('considering', 'working'): 1,
#          ('working', 'proj'): 1,
#          ('table', 'tr'): 3,
#          ('tr', 'td'): 6,
#          ('td', 'td'): 3,
#          ('td', 'tr'): 6,
#          ('tr', 'tr'): 3,
#          ('td', 'representation'): 2,
#          ('representation', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'dogecoin'): 1,
#          ('dogecoin', 'seen'): 1,
#          ('seen', 'illustration'): 2,
#          ('illustration', 'taken'): 2,
#          ('taken', 'november'): 2,
#          ('november', '29'): 1,
#          ('29', '2021'): 1,
#          ('2021', 'reuters'): 2,
#          ('reuters', 'dado'): 2,
#          ('dado', 'ruvic'): 2,
#          ('ruvic', 'illustration'): 2,
#          ('illustration', 'file'): 2,
#          ('file', 'photo'): 2,
#          ('photo', 'td'): 2,
#          ('tr', 'table'): 3,
#          ('table', 'tesla'): 1,
#          ('tesla', 'inc'): 1,
#          ('inc', 'tsla'): 1,
#          ('tsla', 'accept'): 1,
#          ('accept', 'meme'): 1,
#          ('meme', 'based'): 1,
#          ('based', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'dogeco'): 1,
#          ('mr', 'adam'): 1,
#          ('adam', 'want'): 1,
#          ('want', 'new'): 1,
#          ('new', 'york'): 1,
#          ('york', 'city'): 1,
#          ('city', 'become'): 1,
#          ('become', 'global'): 1,
#          ('global', 'capital'): 1,
#          ('capital', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'paycheck'): 1,
#          ('paycheck', 'converted'): 1,
#          ('converted', 'bitcoin'): 1,
#          ('bitcoin', 'ethereum'): 1,
#          ('rock', 'hope'): 1,
#          ('hope', 'new'): 1,
#          ('new', 'stock'): 1,
#          ('stock', 'exchange'): 1,
#          ('exchange', 'attract'): 1,
#          ('attract', 'crypto'): 1,
#          ('crypto', 'millionaire'): 1,
#          ('millionaire', 'want'): 1,
#          ('want', 'avoid'): 1,
#          ('avoid', 'hefty'): 1,
#          ('hefty', 'tax'): 1,
#          ('representation', 'virtual'): 1,
#          ('virtual', 'cryptocurrencies'): 1,
#          ('cryptocurrencies', 'seen'): 1,
#          ('november', '28'): 1,
#          ('28', '2021'): 1,
#          ('table', 'russia'): 1,
#          ('russia', 'central'): 1,
#          ('central', 'bank'): 1,
#          ('bank', 'thursday'): 1,
#          ('thursday', 'proposed'): 1,
#          ('proposed', 'banning'): 1,
#          ('banning', 'use'): 1,
#          ('use', 'mi'): 1,
#          ('official', 'say'): 1,
#          ('say', 'decision'): 1,
#          ('decision', 'pose'): 1,
#          ('pose', 'risk'): 1,
#          ('risk', 'financial'): 1,
#          ('financial', 'stability'): 1,
#          ('stability', 'consumer'): 1,
#          ('consumer', 'protection'): 1,
#          ('protection', 'country'): 1,
#          ('td', 'zhao'): 1,
#          ('zhao', 'changpeng'): 1,
#          ('changpeng', 'become'): 1,
#          ('become', 'world'): 1,
#          ('world', 'biggest'): 1,
#          ('biggest', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'billionaire'): 1,
#          ('billionaire', 'image'): 1,
#          ('image', 'bloomberg'): 1,
#          ('bloomberg', 'via'): 1,
#          ('via', 'getty'): 1,
#          ('getty', 'image'): 1,
#          ('image', 'td'): 1,
#          ('table', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'ceo'): 1,
#          ('ceo', 'become'): 1,
#          ('become', 'one'): 1,
#          ('one', 'richest'): 1,
#          ('richest', 'people'): 1,
#          ('people', 'planet'): 1,
#          ('planet', 'changpeng'): 1,
#          ('changpeng', 'cz'): 1,
#          ('cz', 'zhao'): 1,
#          ('u', 'security'): 1,
#          ('security', 'exchange'): 1,
#          ('exchange', 'commission'): 1,
#          ('commission', 'thursday'): 1,
#          ('thursday', 'rejected'): 1,
#          ('rejected', 'proposal'): 1,
#          ('proposal', 'offer'): 1,
#          ('offer', 'spot'): 1,
#          ('spot', 'bitcoin'): 1,
#          ('bitcoin', 'exchange'): 1,
#          ('exchange', 'traded'): 1,
#          ('traded', 'fund'): 1,
#          ('fund', 'etf'): 1,
#          ('etf', 'fidelity'): 1,
#          ('fidelity', 'wise'): 1,
#          ('wise', 'origin'): 1,
#          ('origin', 'bitcoin'): 1,
#          ('bitcoin', 'trust'): 1,
#          ('block', 'officially'): 1,
#          ('building', 'bitcoin'): 1,
#          ('system', 'make'): 1,
#          ('make', 'mining'): 1,
#          ('mining', 'bitcoin'): 1,
#          ('bitcoin', 'distributed'): 1,
#          ('distributed', 'efficient'): 1,
#          ('bitcoin', 'themed'): 1,
#          ('themed', 'superspreader'): 1,
#          ('superspreader', 'event'): 1,
#          ('event', 'cringey'): 1,
#          ('cringey', 'branded'): 1,
#          ('branded', 'nft'): 1,
#          ('nft', 'within'): 1,
#          ('within', 'crypto'): 1,
#          ('crypto', 'community'): 1,
#          ('community', 'set'): 1,
#          ('set', 'high'): 1,
#          ('high', 'bar'): 1,
#          ('bar', 'devising'): 1,
#          ('devising', 'worst'): 1,
#          ('worst', 'way'): 1,
#          ('way', 'hawk'): 1,
#          ('hawk', 'currency'): 1,
#          ('currency', 'choice'): 1,
#          ('choice', 'week'): 1,
#          ('week', 'creator'): 1,
#          ('creator', 'elon'): 1,
#          ('elon', 'musk'): 1,
#          ('musk', 'themed'): 1,
#          ('themed', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'dubbed'): 1,
#          ('back', 'september'): 1,
#          ('september', 'robinhood'): 1,
#          ('robinhood', 'announced'): 1,
#          ('announced', 'plan'): 1,
#          ('plan', 'test'): 1,
#          ('test', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'wallet'): 1,
#          ('wallet', 'within'): 1,
#          ('within', 'app'): 1,
#          ('app', 'time'): 1,
#          ('time', 'company'): 1,
#          ('company', 'said'): 1,
#          ('said', 'would'): 1,
#          ('would', 'open'): 1,
#          ('open', 'beta'): 1,
#          ('beta', 'small'): 1,
#          ('small', 'number'): 1,
#          ('number', 'people'): 1,
#          ('people', 'expanding'): 1,
#          ('expanding', 'availability'): 1,
#          ('availability', 'ahead'): 1,
#          ('ahead', 'full'): 1,
#          ('full', 'scale'): 1,
#          ('scale', 'release'): 1,
#          ('release', 'joined'): 1,
#          ('joined', 'wait'): 1,
#          ('trading', 'platform'): 1,
#          ('platform', 'crypto'): 1,
#          ('com', 'lost'): 1,
#          ('lost', '34'): 1,
#          ('34', 'million'): 1,
#          ('million', 'worth'): 1,
#          ('worth', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'hack'): 1,
#          ('hack', 'monday'): 1,
#          ('monday', 'according'): 1,
#          ('according', 'new'): 1,
#          ('new', 'blog'): 1,
#          ('blog', 'post'): 1,
#          ('post', 'company'): 1,
#          ('company', 'published'): 1,
#          ('published', 'overnight'): 1,
#          ('overnight', 'company'): 1,
#          ('company', 'previously'): 1,
#          ('previously', 'declined'): 1,
#          ('declined', 'say'): 1,
#          ('say', 'much'): 1,
#          ('much', 'hack'): 1,
#          ('hack', 'forced'): 1,
#          ('forced', 'user'): 1,
#          ('user', 'stop'): 1,
#          ('stop', 'withdra'): 1,
#          ('one', 'european'): 1,
#          ('european', 'union'): 1,
#          ('union', 'top'): 1,
#          ('top', 'regulator'): 1,
#          ('regulator', 'new'): 1,
#          ('new', 'proposal'): 1,
#          ('proposal', 'reducing'): 1,
#          ('reducing', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'carbon'): 1,
#          ('carbon', 'footprint'): 1,
#          ('footprint', 'ban'): 1,
#          ('ban', 'proof'): 1,
#          ('proof', 'work'): 1,
#          ('work', 'mining'): 1,
#          ('mining', 'proposed'): 1,
#          ('proposed', 'prohibition'): 1,
#          ('prohibition', 'suggested'): 1,
#          ('suggested', 'european'): 1,
#          ('european', 'security'): 1,
#          ('security', 'market'): 1,
#          ('market', 'authority'): 1,
#          ('authority', 'vice'): 1,
#          ('vice', 'chair'): 1,
#          ('chair', 'erik'): 1,
#          ('erik', 'thedéen'): 1,
#          ('thedéen', 'financial'): 1,
#          ('bitcoin', 'beginning'): 1,
#          ('beginning', 'reassert'): 1,
#          ('reassert', 'dominance'): 1,
#          ('dominance', 'challenger'): 1,
#          ('challenger', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'crown'): 1})

# %%
# Generate the Ethereum N-grams where N=2
ngram_list = []
for text_type in [eth_title, eth_text]:
    eth_ngram = []
    for text in text_type:
        eth_ngram += ngrams(text, n=2)
    eth_ngram = Counter(eth_ngram)
    ngram_list.append(eth_ngram)

eth_title_ngram = ngram_list[0]
eth_text_ngram = ngram_list[1]

display(eth_title_ngram)
display(eth_text_ngram)
# Out:
# Counter({('crypto', 'com'): 4,
#          ('com', 'admits'): 1,
#          ('admits', '30'): 1,
#          ('30', 'million'): 1,
#          ('million', 'stolen'): 3,
#          ('stolen', 'hacker'): 3,
#          ('hacker', 'launder'): 1,
#          ('launder', '15'): 1,
#          ('15', 'million'): 1,
#          ('stolen', 'crypto'): 1,
#          ('com', 'using'): 1,
#          ('using', 'ethereum'): 1,
#          ('ethereum', 'mixer'): 1,
#          ('eric', 'adam'): 2,
#          ('adam', 'taking'): 1,
#          ('taking', 'first'): 1,
#          ('first', 'paycheck'): 2,
#          ('paycheck', 'crypto'): 1,
#          ('robinhood', 'open'): 1,
#          ('open', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'wallet'): 1,
#          ('wallet', 'beta'): 1,
#          ('beta', 'tester'): 1,
#          ('com', 'finally'): 1,
#          ('finally', 'acknowledges'): 1,
#          ('acknowledges', '34'): 1,
#          ('34', 'million'): 2,
#          ('looksrare', 'reportedly'): 1,
#          ('reportedly', 'generated'): 1,
#          ('generated', '8b'): 1,
#          ('8b', 'ethereum'): 1,
#          ('ethereum', 'nft'): 1,
#          ('nft', 'wash'): 1,
#          ('wash', 'trading'): 1,
#          ('mine', 'ethereum'): 1,
#          ('ethereum', 'step'): 1,
#          ('step', 'step'): 1,
#          ('step', 'guide'): 1,
#          ('2', 'meme'): 1,
#          ('meme', 'stock'): 1,
#          ('stock', 'beat'): 1,
#          ('beat', 'ethereum'): 1,
#          ('ethereum', '2021'): 1,
#          ('ethereum', 'inventor'): 1,
#          ('inventor', 'want'): 1,
#          ('want', 'replace'): 1,
#          ('replace', 'pregnant'): 1,
#          ('pregnant', 'woman'): 1,
#          ('woman', 'synthetic'): 1,
#          ('synthetic', 'womb'): 1,
#          ('crypto', 'exchange'): 1,
#          ('exchange', 'shuts'): 1,
#          ('shuts', 'withdrawal'): 1,
#          ('withdrawal', 'hacker'): 1,
#          ('hacker', 'reportedly'): 1,
#          ('reportedly', 'steal'): 1,
#          ('steal', '33'): 1,
#          ('33', 'million'): 1,
#          ('million', 'bitcoin'): 1,
#          ('bitcoin', 'ethereum'): 1,
#          ('race', 'dominate'): 1,
#          ('dominate', 'defi'): 1,
#          ('defi', 'ecosystem'): 2,
#          ('race', 'power'): 1,
#          ('power', 'defi'): 1,
#          ('blockchain', 'platform'): 2,
#          ('platform', 'wormhole'): 2,
#          ('wormhole', 'say'): 1,
#          ('say', 'retrieved'): 1,
#          ('retrieved', '324m'): 1,
#          ('324m', 'stolen'): 1,
#          ('hacker', 'cnet'): 1,
#          ('hacker', 'steal'): 1,
#          ('steal', '320m'): 1,
#          ('320m', 'blockchain'): 1,
#          ('wormhole', 'cnet'): 1,
#          ('com', 'loses'): 1,
#          ('loses', '34'): 1,
#          ('million', 'hack'): 1,
#          ('hack', 'affected'): 1,
#          ('affected', '483'): 1,
#          ('483', 'account'): 1,
#          ('gibraltar', 'could'): 1,
#          ('could', 'launch'): 1,
#          ('launch', 'world'): 1,
#          ('world', 'first'): 1,
#          ('first', 'crypto'): 1,
#          ('crypto', 'stock'): 1,
#          ('stock', 'exchange'): 1,
#          ('bitcoin', 'surge'): 1,
#          ('surge', '8'): 1,
#          ('8', '82'): 1,
#          ('82', '40611'): 1,
#          ('40611', 'reuters'): 1,
#          ('blockchain', 'could'): 1,
#          ('could', 'solve'): 1,
#          ('solve', 'problem'): 1,
#          ('problem', 'digital'): 1,
#          ('digital', 'identity'): 1,
#          ('new', 'york'): 1,
#          ('york', 'city'): 1,
#          ('city', 'mayor'): 1,
#          ('mayor', 'eric'): 1,
#          ('adam', 'convert'): 1,
#          ('convert', 'first'): 1,
#          ('paycheck', 'cryptocurrency'): 1,
#          ('gamestop', 'tap'): 1,
#          ('tap', 'immutable'): 1,
#          ('immutable', 'x'): 1,
#          ('x', 'nft'): 1,
#          ('nft', 'marketplace'): 1,
#          ('marketplace', 'reuters'): 1})
# Counter({('cryptocurrency', 'exchange'): 1,
#          ('exchange', 'crypto'): 1,
#          ('crypto', 'com'): 5,
#          ('com', 'said'): 1,
#          ('said', '15'): 1,
#          ('15', 'million'): 2,
#          ('million', 'ethereum'): 2,
#          ('ethereum', '18'): 1,
#          ('18', 'million'): 1,
#          ('million', 'bitcoin'): 1,
#          ('bitcoin', 'stolen'): 1,
#          ('stolen', 'hacker'): 1,
#          ('hacker', 'security'): 1,
#          ('security', 'breach'): 1,
#          ('hacker', 'made'): 1,
#          ('made', 'roughly'): 1,
#          ('roughly', '15'): 1,
#          ('ethereum', 'crypto'): 1,
#          ('com', 'attempting'): 1,
#          ('attempting', 'launder'): 1,
#          ('launder', 'fund'): 1,
#          ('fund', 'called'): 1,
#          ('called', 'ethereum'): 1,
#          ('ethereum', 'mixer'): 1,
#          ('mixer', 'known'): 1,
#          ('known', 'tornado'): 1,
#          ('tornado', 'cash'): 1,
#          ('cash', 'according'): 1,
#          ('according', 'new'): 2,
#          ('new', 'report'): 1,
#          ('report', 'crypto'): 1,
#          ('crypto', 'security'): 1,
#          ('security', 'company'): 1,
#          ('company', 'peck'): 1,
#          ('peck', 'shield'): 1,
#          ('shield', 'mixer'): 1,
#          ('mixer', 'run'): 1,
#          ('run', 'interfere'): 1,
#          ('mr', 'adam'): 1,
#          ('adam', 'want'): 1,
#          ('want', 'new'): 1,
#          ('new', 'york'): 2,
#          ('york', 'city'): 2,
#          ('city', 'become'): 1,
#          ('become', 'global'): 1,
#          ('global', 'capital'): 1,
#          ('capital', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'paycheck'): 1,
#          ('paycheck', 'converted'): 1,
#          ('converted', 'bitcoin'): 2,
#          ('bitcoin', 'ethereum'): 2,
#          ('back', 'september'): 1,
#          ('september', 'robinhood'): 1,
#          ('robinhood', 'announced'): 1,
#          ('announced', 'plan'): 1,
#          ('plan', 'test'): 1,
#          ('test', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'wallet'): 1,
#          ('wallet', 'within'): 1,
#          ('within', 'app'): 1,
#          ('app', 'time'): 1,
#          ('time', 'company'): 1,
#          ('company', 'said'): 1,
#          ('said', 'would'): 1,
#          ('would', 'open'): 1,
#          ('open', 'beta'): 1,
#          ('beta', 'small'): 1,
#          ('small', 'number'): 1,
#          ('number', 'people'): 1,
#          ('people', 'expanding'): 1,
#          ('expanding', 'availability'): 1,
#          ('availability', 'ahead'): 1,
#          ('ahead', 'full'): 1,
#          ('full', 'scale'): 1,
#          ('scale', 'release'): 1,
#          ('release', 'joined'): 1,
#          ('joined', 'wait'): 1,
#          ('trading', 'platform'): 1,
#          ('platform', 'crypto'): 1,
#          ('com', 'lost'): 1,
#          ('lost', '34'): 1,
#          ('34', 'million'): 1,
#          ('million', 'worth'): 1,
#          ('worth', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'hack'): 1,
#          ('hack', 'monday'): 1,
#          ('monday', 'according'): 1,
#          ('new', 'blog'): 1,
#          ('blog', 'post'): 1,
#          ('post', 'company'): 1,
#          ('company', 'published'): 1,
#          ('published', 'overnight'): 1,
#          ('overnight', 'company'): 1,
#          ('company', 'previously'): 1,
#          ('previously', 'declined'): 1,
#          ('declined', 'say'): 1,
#          ('say', 'much'): 1,
#          ('much', 'hack'): 1,
#          ('hack', 'forced'): 1,
#          ('forced', 'user'): 1,
#          ('user', 'stop'): 1,
#          ('stop', 'withdra'): 1,
#          ('looksrare', 'seemingly'): 1,
#          ('seemingly', 'came'): 1,
#          ('came', 'nowhere'): 1,
#          ('nowhere', 'become'): 1,
#          ('become', 'biggest'): 1,
#          ('biggest', 'rival'): 1,
#          ('rival', 'yet'): 1,
#          ('yet', 'leading'): 1,
#          ('leading', 'nft'): 1,
#          ('nft', 'marketplace'): 2,
#          ('marketplace', 'opensea'): 1,
#          ('opensea', 'earlier'): 1,
#          ('earlier', 'month'): 1,
#          ('month', 'big'): 1,
#          ('big', 'asterisk'): 1,
#          ('asterisk', 'astronomical'): 1,
#          ('astronomical', 'trading'): 1,
#          ('trading', 'figure'): 1,
#          ('figure', 'coming'): 1,
#          ('coming', 'platform'): 1,
#          ('platform', 'report'): 1,
#          ('report', 'marred'): 1,
#          ('marred', 'rampant'): 1,
#          ('ethereum', 'mining'): 1,
#          ('mining', 'lot'): 1,
#          ('lot', 'accessible'): 1,
#          ('accessible', 'everything'): 1,
#          ('everything', 'know'): 1,
#          ('know', 'mine'): 1,
#          ('mine', 'ether'): 1,
#          ('investor', 'interest'): 1,
#          ('interest', 'growing'): 1,
#          ('growing', 'cryptocurrency'): 1,
#          ('cryptocurrency', 'uptake'): 1,
#          ('uptake', 'helped'): 1,
#          ('helped', 'ethereum'): 1,
#          ('ethereum', 'surge'): 1,
#          ('surge', '418'): 1,
#          ('418', '2021'): 1,
#          ('2021', 'however'): 1,
#          ('however', 'meme'): 1,
#          ('meme', 'stock'): 1,
#          ('stock', 'amc'): 1,
#          ('amc', 'entertainment'): 1,
#          ('entertainment', 'amc'): 1,
#          ('amc', 'gamestop'): 1,
#          ('gamestop', 'gme'): 1,
#          ('gme', 'beat'): 1,
#          ('beat', 'ethereum'): 1,
#          ('ethereum', 'return'): 1,
#          ('return', 'soaring'): 1,
#          ('soaring', '650'): 1,
#          ('650', 'price'): 1,
#          ('crypto', 'bros'): 1,
#          ('bros', 'never'): 1,
#          ('never', 'tire'): 1,
#          ('tire', 'sharing'): 1,
#          ('sharing', 'utopian'): 1,
#          ('utopian', 'vision'): 1,
#          ('vision', 'big'): 1,
#          ('big', 'brain'): 1,
#          ('brain', 'idea'): 1,
#          ('idea', 'always'): 1,
#          ('always', 'embraced'): 1,
#          ('embraced', 'prole'): 1,
#          ('prole', 'vitalik'): 1,
#          ('vitalik', 'buterin'): 2,
#          ('buterin', 'co'): 1,
#          ('co', 'founder'): 1,
#          ('founder', 'inventor'): 1,
#          ('inventor', 'ethereum'): 1,
#          ('ethereum', 'become'): 1,
#          ('become', 'latest'): 1,
#          ('latest', 'victim'): 1,
#          ('victim', 'insolence'): 1,
#          ('insolence', '27'): 1,
#          ('27', 'year'): 1,
#          ('year', 'old'): 1,
#          ('old', 'pitched'): 1,
#          ('pitched', 'bo'): 1,
#          ('com', 'issued'): 1,
#          ('issued', 'statement'): 1,
#          ('statement', 'multiple'): 1,
#          ('multiple', 'user'): 1,
#          ('user', 'reported'): 1,
#          ('reported', 'suspicious'): 1,
#          ('suspicious', 'activity'): 1,
#          ('activity', 'account'): 1,
#          ('ethereum', 'losing'): 2,
#          ('losing', 'market'): 2,
#          ('market', 'share'): 2,
#          ('developer', 'behind'): 2,
#          ('behind', 'popular'): 2,
#          ('popular', 'blockchain'): 2,
#          ('blockchain', 'bridge'): 2,
#          ('bridge', 'say'): 1,
#          ('say', 'service'): 1,
#          ('service', 'back'): 1,
#          ('bridge', 'offer'): 1,
#          ('offer', 'hacker'): 1,
#          ('hacker', '10'): 1,
#          ('10', 'million'): 1,
#          ('million', 'bug'): 1,
#          ('bug', 'bounty'): 1,
#          ('bounty', 'info'): 1,
#          ('info', 'exploit'): 1,
#          ('exploit', 'return'): 1,
#          ('return', 'stolen'): 1,
#          ('stolen', 'cryptocurrency'): 1,
#          ('interview', 'bloomberg'): 1,
#          ('bloomberg', 'tv'): 1,
#          ('tv', 'crypto'): 1,
#          ('com', 'chief'): 1,
#          ('chief', 'executive'): 1,
#          ('executive', 'kris'): 1,
#          ('kris', 'marszalek'): 1,
#          ('marszalek', 'admitted'): 1,
#          ('admitted', '400'): 1,
#          ('400', 'customer'): 1,
#          ('customer', 'account'): 1,
#          ('account', 'compromised'): 1,
#          ('compromised', 'hacker'): 1,
#          ('hacker', 'said'): 1,
#          ('said', 'team'): 1,
#          ('team', 'detected'): 1,
#          ('detected', 'unauthorized'): 1,
#          ('unauthorized', 'transaction'): 1,
#          ('transaction', 'made'): 1,
#          ('made', 'account'): 1,
#          ('account', 'fixed'): 1,
#          ('fixed', 'issue'): 1,
#          ('issue', 'imm'): 1,
#          ('rock', 'hope'): 1,
#          ('hope', 'new'): 1,
#          ('new', 'stock'): 1,
#          ('stock', 'exchange'): 1,
#          ('exchange', 'attract'): 1,
#          ('attract', 'crypto'): 1,
#          ('crypto', 'millionaire'): 1,
#          ('millionaire', 'want'): 1,
#          ('want', 'avoid'): 1,
#          ('avoid', 'hefty'): 1,
#          ('hefty', 'tax'): 1,
#          ('bitcoin', 'surged'): 1,
#          ('surged', '8'): 1,
#          ('8', '82'): 1,
#          ('82', '40'): 1,
#          ('40', '611'): 1,
#          ('611', '4'): 1,
#          ('4', '2202'): 1,
#          ('2202', 'gmt'): 1,
#          ('gmt', 'friday'): 1,
#          ('friday', 'adding'): 1,
#          ('adding', '3'): 1,
#          ('3', '291'): 1,
#          ('291', '29'): 1,
#          ('29', 'previous'): 1,
#          ('previous', 'close'): 1,
#          ('buterin', 'founder'): 1,
#          ('founder', 'ethereum'): 1,
#          ('ethereum', 'asked'): 1,
#          ('asked', 'lately'): 1,
#          ('lately', 'favorite'): 1,
#          ('favorite', 'project'): 1,
#          ('project', 'built'): 1,
#          ('built', 'blockchain'): 1,
#          ('blockchain', 'often'): 1,
#          ('often', 'name'): 1,
#          ('name', 'proof'): 1,
#          ('proof', 'humanity'): 1,
#          ('city', 'mayor'): 1,
#          ('mayor', 'eric'): 1,
#          ('eric', 'adam'): 1,
#          ('adam', 'confirmed'): 1,
#          ('confirmed', 'first'): 1,
#          ('first', 'paycheck'): 1,
#          ('paycheck', 'arrives'): 1,
#          ('arrives', 'friday'): 1,
#          ('friday', 'converted'): 1,
#          ('gamestop', 'corp'): 1,
#          ('corp', 'href'): 1,
#          ('href', 'http'): 1,
#          ('http', 'www'): 1,
#          ('www', 'reuters'): 1,
#          ('reuters', 'com'): 1,
#          ('com', 'company'): 1,
#          ('company', 'gme'): 1,
#          ('gme', 'n'): 2,
#          ('n', 'target'): 1,
#          ('target', '_blank'): 1,
#          ('_blank', 'gme'): 1,
#          ('n', 'partnering'): 1,
#          ('partnering', 'blockchain'): 1,
#          ('blockchain', 'startup'): 1,
#          ('startup', 'immutable'): 1,
#          ('immutable', 'x'): 1,
#          ('x', 'launch'): 1,
#          ('launch', 'non'): 1,
#          ('non', 'fungible'): 1,
#          ('fungible', 'token'): 1,
#          ('token', 'nft'): 1,
#          ('marketplace', 'later'): 1,
#          ('later', 'year'): 1,
#          ('year', 'look'): 1,
#          ('look', 'take'): 1,
#          ('take', 'advantage'): 1,
#          ('advantage', 'booming'): 1,
#          ('booming', 'mark'): 1})

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
btc_title_token = []
for lists in bitcoin_title:
    btc_title_token += lists
    
btc_text_token = []
for lists in bitcoin_text:
    btc_text_token += lists    
    
display(token_count(btc_title_token))
display(token_count(btc_text_token))
# Out:
# [('crypto', 9), ('bitcoin', 8), ('mining', 5)]
# [('bitcoin', 15), ('cryptocurrency', 12), ('tr', 12)]

# %%
# Use token_count to get the top 10 words for Ethereum
eth_title_token = []
for lists in eth_title:
    eth_title_token += lists
    
eth_text_token = []
for lists in eth_text:
    eth_text_token += lists    
    
display(token_count(eth_title_token))
display(token_count(eth_text_token))
# Out:
# [('crypto', 7), ('hacker', 6), ('ethereum', 6)]
# [('ethereum', 12), ('crypto', 8), ('cryptocurrency', 6)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
btc_wc_title = WordCloud().generate(' '.join(btc_title_token))
print('BTC title wordcloud')
plt.imshow(btc_wc_title)
# Out:
# BTC title wordcloud

# %%
btc_wc_text= WordCloud().generate(' '.join(btc_text_token))
print('BTC text wordcloud')
plt.imshow(btc_wc_text)
# Out:
# BTC text wordcloud

# %%
# Generate the Ethereum word cloud
eth_wc_title = WordCloud().generate(' '.join(eth_title_token))
print('ETH text wordcloud')
plt.imshow(eth_wc_title)
# Out:
# ETH text wordcloud

# %%
eth_wc_text= WordCloud().generate(' '.join(eth_text_token))
print('ETH text wordcloud')
plt.imshow(eth_wc_text)
# Out:
# ETH text wordcloud

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
# !python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together

# %%
# Run the NER processor on all of the text
doc_btc_title = nlp(' '.join(btc_title_token))
# Add a title to the document
print('BTC title NER')
# Render NER visualization with displacy
displacy.render(doc, style='ent')
print('______________________________________')
print('')
doc_btc_text = nlp(' '.join(btc_text_token))
# Add a title to the document
print('BTC text NER')
# Render NER visualization with displacy
displacy.render(doc, style='ent')
# Out:
# BTC title NER
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">cryptocurrency exchange crypto com said
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ethereum
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     18 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  bitcoin stolen hacker security breach hacker made
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     roughly 15 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ethereum crypto com attempting launder fund called ethereum mixer known tornado cash according new report crypto security company peck shield mixer run interfere mr adam want
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     new york city
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  become global capital cryptocurrency paycheck converted bitcoin ethereum back
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     september
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  robinhood announced plan test cryptocurrency wallet within app time company said would open beta small number people expanding availability ahead full scale release joined wait trading platform crypto com lost
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     34 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  worth cryptocurrency hack
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  according new blog post company published overnight company previously declined say much hack forced user stop withdra looksrare seemingly came nowhere become biggest rival yet leading nft marketplace opensea
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     earlier month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  big asterisk astronomical trading figure coming platform report marred rampant ethereum mining lot accessible everything know mine ether investor interest growing cryptocurrency uptake helped ethereum surge
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     418 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  however meme stock amc entertainment amc gamestop gme beat ethereum return soaring
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     650
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  price crypto bros never tire sharing utopian vision big brain idea always embraced prole vitalik buterin co founder inventor ethereum become latest victim insolence
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     27 year old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  pitched bo crypto com issued statement multiple user reported suspicious activity account ethereum losing market share ethereum losing market share developer behind popular blockchain bridge say service back developer behind popular blockchain bridge offer hacker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  bug bounty info exploit return stolen cryptocurrency interview bloomberg tv crypto com chief executive
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kris marszalek
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  admitted
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     400
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  customer account compromised hacker said team detected unauthorized transaction made account fixed issue imm rock hope new stock exchange attract crypto millionaire want avoid hefty tax bitcoin surged 8 82 40 611 4 2202 gmt friday adding
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3 291
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     29
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  previous close vitalik buterin founder ethereum asked lately favorite project built blockchain often name proof humanity
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     new york city
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  mayor
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eric adam
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  confirmed
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  paycheck arrives
# <mark class="entity" style="background: #bfe1d
# ______________________________________
#
# BTC text NER
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">cryptocurrency exchange crypto com said
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ethereum
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     18 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  bitcoin stolen hacker security breach hacker made
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     roughly 15 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ethereum crypto com attempting launder fund called ethereum mixer known tornado cash according new report crypto security company peck shield mixer run interfere mr adam want
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     new york city
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  become global capital cryptocurrency paycheck converted bitcoin ethereum back
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     september
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  robinhood announced plan test cryptocurrency wallet within app time company said would open beta small number people expanding availability ahead full scale release joined wait trading platform crypto com lost
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     34 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  worth cryptocurrency hack
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  according new blog post company published overnight company previously declined say much hack forced user stop withdra looksrare seemingly came nowhere become biggest rival yet leading nft marketplace opensea
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     earlier month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  big asterisk astronomical trading figure coming platform report marred rampant ethereum mining lot accessible everything know mine ether investor interest growing cryptocurrency uptake helped ethereum surge
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     418 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  however meme stock amc entertainment amc gamestop gme beat ethereum return soaring
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     650
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  price crypto bros never tire sharing utopian vision big brain idea always embraced prole vitalik buterin co founder inventor ethereum become latest victim insolence
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     27 year old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  pitched bo crypto com issued statement multiple user reported suspicious activity account ethereum losing market share ethereum losing market share developer behind popular blockchain bridge say service back developer behind popular blockchain bridge offer hacker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  bug bounty info exploit return stolen cryptocurrency interview bloomberg tv crypto com chief executive
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kris marszalek
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  admitted
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     400
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  customer account compromised hacker said team detected unauthorized transaction made account fixed issue imm rock hope new stock exchange attract crypto millionaire want avoid hefty tax bitcoin surged 8 82 40 611 4 2202 gmt friday adding
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3 291
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     29
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  previous close vitalik buterin founder ethereum asked lately favorite project built blockchain often name proof humanity
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     new york city
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  mayor
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eric adam
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  confirmed
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  paycheck arrives
# <mark class="entity" style="background: #bfe1d

# %%
# Render the visualization
# YOUR CODE HERE!

# %%
# List all Entities
print('BTC title entities')
print([ent.text for ent in doc_btc_title.ents])
print('')
print('BTC text entities')
print([ent.text for ent in doc_btc_text.ents])
# Out:
# BTC title entities
# ['kazakhstan', 'el salvador', 'jack dorsey', 'eight year', '30 million', '50', 'jack dorsey', 'first', 'first', 'russian', 'el salvador', 'one', 'sec', 'reuters', 'jack dorsey', '500', '34 million']
#
# BTC text entities
# ['central asian country', '2', 'el salvador', 'jack dorsey', 'eight year', '15 million', '18 million', 'saturday', '50', 'november', '600 billion', '1 trillion', 'jack dorsey', 'first', 'october last year', 'november 29 2021', 'reuters', 'new york city', 'november 28 2021', 'reuters', 'russia', 'thursday', 'zhao changpeng', 'one', 'changpeng', 'zhao u security exchange commission', 'thursday', 'september', '34 million', 'monday', 'one', 'european']

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
# YOUR CODE HERE!

# %%
# Run the NER processor on all of the text
doc_eth_title = nlp(' '.join(eth_title_token))
# Add a title to the document
print('ETH title NER')
# Render NER visualization with displacy
displacy.render(doc, style='ent')
print('______________________________________')
print('')
doc_eth_text = nlp(' '.join(eth_text_token))
# Add a title to the document
print('ETH text NER')
# Render NER visualization with displacy
displacy.render(doc, style='ent')
# Out:
# ETH title NER
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">cryptocurrency exchange crypto com said
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ethereum
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     18 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  bitcoin stolen hacker security breach hacker made
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     roughly 15 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ethereum crypto com attempting launder fund called ethereum mixer known tornado cash according new report crypto security company peck shield mixer run interfere mr adam want
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     new york city
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  become global capital cryptocurrency paycheck converted bitcoin ethereum back
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     september
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  robinhood announced plan test cryptocurrency wallet within app time company said would open beta small number people expanding availability ahead full scale release joined wait trading platform crypto com lost
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     34 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  worth cryptocurrency hack
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  according new blog post company published overnight company previously declined say much hack forced user stop withdra looksrare seemingly came nowhere become biggest rival yet leading nft marketplace opensea
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     earlier month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  big asterisk astronomical trading figure coming platform report marred rampant ethereum mining lot accessible everything know mine ether investor interest growing cryptocurrency uptake helped ethereum surge
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     418 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  however meme stock amc entertainment amc gamestop gme beat ethereum return soaring
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     650
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  price crypto bros never tire sharing utopian vision big brain idea always embraced prole vitalik buterin co founder inventor ethereum become latest victim insolence
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     27 year old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  pitched bo crypto com issued statement multiple user reported suspicious activity account ethereum losing market share ethereum losing market share developer behind popular blockchain bridge say service back developer behind popular blockchain bridge offer hacker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  bug bounty info exploit return stolen cryptocurrency interview bloomberg tv crypto com chief executive
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kris marszalek
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  admitted
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     400
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  customer account compromised hacker said team detected unauthorized transaction made account fixed issue imm rock hope new stock exchange attract crypto millionaire want avoid hefty tax bitcoin surged 8 82 40 611 4 2202 gmt friday adding
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3 291
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     29
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  previous close vitalik buterin founder ethereum asked lately favorite project built blockchain often name proof humanity
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     new york city
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  mayor
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eric adam
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  confirmed
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  paycheck arrives
# <mark class="entity" style="background: #bfe1d
# ______________________________________
# ETH text NER
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">cryptocurrency exchange crypto com said
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     15 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ethereum
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     18 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  bitcoin stolen hacker security breach hacker made
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     roughly 15 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ethereum crypto com attempting launder fund called ethereum mixer known tornado cash according new report crypto security company peck shield mixer run interfere mr adam want
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     new york city
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  become global capital cryptocurrency paycheck converted bitcoin ethereum back
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     september
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  robinhood announced plan test cryptocurrency wallet within app time company said would open beta small number people expanding availability ahead full scale release joined wait trading platform crypto com lost
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     34 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  worth cryptocurrency hack
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  according new blog post company published overnight company previously declined say much hack forced user stop withdra looksrare seemingly came nowhere become biggest rival yet leading nft marketplace opensea
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     earlier month
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  big asterisk astronomical trading figure coming platform report marred rampant ethereum mining lot accessible everything know mine ether investor interest growing cryptocurrency uptake helped ethereum surge
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     418 2021
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  however meme stock amc entertainment amc gamestop gme beat ethereum return soaring
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     650
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  price crypto bros never tire sharing utopian vision big brain idea always embraced prole vitalik buterin co founder inventor ethereum become latest victim insolence
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     27 year old
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  pitched bo crypto com issued statement multiple user reported suspicious activity account ethereum losing market share ethereum losing market share developer behind popular blockchain bridge say service back developer behind popular blockchain bridge offer hacker
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     10 million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  bug bounty info exploit return stolen cryptocurrency interview bloomberg tv crypto com chief executive
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     kris marszalek
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  admitted
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     400
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  customer account compromised hacker said team detected unauthorized transaction made account fixed issue imm rock hope new stock exchange attract crypto millionaire want avoid hefty tax bitcoin surged 8 82 40 611 4 2202 gmt friday adding
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3 291
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     29
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  previous close vitalik buterin founder ethereum asked lately favorite project built blockchain often name proof humanity
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     new york city
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  mayor
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     eric adam
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  confirmed
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     first
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORDINAL</span>
# </mark>
#  paycheck arrives
# <mark class="entity" style="background: #bfe1d

# %%
# Render the visualization
# YOUR CODE HERE!

# %%
# List all Entities
print('ETH title entities')
print([ent.text for ent in doc_eth_title.ents])
print('')
print('ETH text entities')
print([ent.text for ent in doc_eth_text.ents])
# Out:
# ETH title entities
# ['30 million', '15 million', 'eric adam', 'first', '34 million', '8b', '2', '2021', '33 million', '324', '320', '34 million', '483', 'first', '8 82 40611', 'reuters', 'new york city', 'eric adam', 'first']
#
# ETH text entities
# ['15 million', '18 million', 'roughly 15 million', 'new york city', 'september', '34 million', 'monday', 'earlier month', '418 2021', '650', '27 year old', '10 million', 'kris marszalek', '400', '3 291', '29', 'new york city', 'eric adam', 'first', 'friday', 'later year']

# %% [markdown]
# ---
